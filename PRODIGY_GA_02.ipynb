# %% [markdown]
# <a href="https://colab.research.google.com/github/Nsi20/PRODIGY_GA_02/blob/main/PRODIGY_GA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRODIGY_GA_02**
# # **Image Generation with Pre-trained Models**
#
# **Task: Utilize pre-trained generative models like DALL-E-mini or Stable Diffusion to create images from text prompts.**
#
# **Step 1: Installing Required Libraries**

# %%
# !pip install diffusers transformers accelerate scipy ftfy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Step 2: Loading Stable Diffusion Model**

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe = pipe.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %% [markdown]
# **Step 5: Generating an Image**

# %%
prompt = "A futuristic cityscape with flying cars and neon lights at night"

# Generating the image
image = pipe(prompt).images[0]

# Displaying the image in Colab
from IPython.display import display
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image.save("generated_image.png")

from google.colab import files
files.download("generated_image.png")

# %%
prompt = "Donald Trump and Elon Musk drinking breakfast together"

# %%
image = pipe(prompt).images[0]
display(image) # Remove the extra space before display
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# !pip install --upgrade diffusers transformers

from diffusers import StableDiffusionPipeline
import torch
from IPython.display import display

# If you have a GPU available you can use it for faster processing
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# Make sure that pipe is initialized before this line
# and that the model weights are downloaded
print(type(pipe))
prompt = "Donald Trump and Elon Musk drinking breakfast together"
print(f"Prompt length: {len(prompt)}")
image = pipe(prompt).images[0]
display(image)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 60.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.2
#     Uninstalling transformers-4.46.2:
#       Successfully uninstalled transformers-4.46.2
# ...
# <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'>
# Prompt length: 54
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "Elon Musk in his spaceship, Starship, realistic, detailed, high-quality"

# %%
image = pipe(prompt).images[0]
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image.save("elon_in_spaceship.png")
from google.colab import files
files.download("elon_in_spaceship.png")

# %%
prompt = "Father Christmas giving a live chicken to a smiling boy child, realistic, detailed, Christmas scene"

# %%
image = pipe(prompt).images[0]
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image.save("santa_chicken_boy.png")
from google.colab import files
files.download("santa_chicken_boy.png")
